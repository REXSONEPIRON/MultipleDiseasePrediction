# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
import pickle as pkl

# %%
df = pd.read_csv('cardio_1.csv')

# %%
df#gender 1- women, 2- men
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 64771       1     165    80.0    150     80            1     1      0     0
# 64772       1     158   126.0    140     90            2     2      0     0
# 64773       2     183   105.0    180     90            3     1      0     1
# 64774       1     163    72.0    135     80            1     2      0     0
# 64775       1     170    72.0    120     80            2     1      0     0
#
#        cardio  Exact_Age
# 0           0         50
# 1           1         55
# 2           1         51
# 3           1         48
# 4           0         47
# ...       ...        ...
# 64771       1         57
# 64772       1         61
# 64773       1         52
# 64774       1         61
# 64775       0         56
#
# [64776 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc',
#        'smoke', 'alco', 'cardio', 'Exact_Age'],
#       dtype='object')

# %%
X = df[['gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc',
       'smoke', 'alco', 'Exact_Age']]

# %%
Y = df['cardio']

# %%
#x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.3,random_state = 42)
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
x_train.shape
# Out:
# (51820, 10)

# %%
x_test.shape
# Out:
# (12956, 10)

# %%
y_train.shape
# Out:
# (51820,)

# %%
y_test.shape
# Out:
# (12956,)

# %% [markdown]
# # Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
y_pred

# %%
model.score(x_train,y_train)

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import confusion_matrix, classification_report,precision_score

# %%
lacc = accuracy_score(y_test,y_pred)

# %%
lacc

# %%
confusion_matrix(y_test,y_pred)

# %%
acc = ((7918+2459)/(7918+2459+3385+6932))#TP+TN/TP+TN+FP+PN
print('accuracy',acc)

# %%
print(classification_report(y_test,y_pred))

# %% [markdown]
# # Naive Bayes Classifier

# %%
model1 = KNeighborsClassifier()

# %%
model1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred1 = model1.predict(x_test)

# %%
y_pred1
# Out:
# array([1, 0, 1, ..., 0, 1, 0], shape=(19433,))

# %%
from sklearn.metrics import accuracy_score

# %%
acc1 = accuracy_score(y_test,y_pred1)

# %%
acc1
# Out:
# 0.682550301034323

# %%
from sklearn.metrics import confusion_matrix, classification_report,precision_score

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68      9432
#            1       0.70      0.68      0.69     10001
#
#     accuracy                           0.68     19433
#    macro avg       0.68      0.68      0.68     19433
# weighted avg       0.68      0.68      0.68     19433

# %% [markdown]
# # Finding Best Model

# %%
print('naive bayes classifier',acc1)
# Out:
# naive bayes classifier 0.682550301034323

# %% [markdown]
# # naive bayes classifieis the best model with the best accuracy of 68%

# %%
d = pkl.dump(model1,open('Heart.pkl','wb'))

# %%
X
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 64771       1     165    80.0    150     80            1     1      0     0
# 64772       1     158   126.0    140     90            2     2      0     0
# 64773       2     183   105.0    180     90            3     1      0     1
# 64774       1     163    72.0    135     80            1     2      0     0
# 64775       1     170    72.0    120     80            2     1      0     0
#
#        Exact_Age
# 0             50
# 1             55
# 2             51
# 3             48
# 4             47
# ...          ...
# 64771         57
# 64772         61
# 64773         52
# 64774         61
# 64775         56
#
# [64776 rows x 10 columns]
